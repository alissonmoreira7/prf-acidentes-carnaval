# %%
import sys
import os
from dotenv import load_dotenv
sys.path.append(os.path.abspath("../"))
from databases.conector import ConectorBanco
load_dotenv()

prf_db_url = os.getenv('DB_CONNECTION_STRING')
conexao = ConectorBanco(prf_db_url)

# Cria o motor de conexão para o banco de dados
engine = conexao.conectar_banco()

df = conexao.carregar_dataframe_acidentes(engine)
print(f'O número de registro é: {len(df)}')

df.head()
# Out:
# Conexão com o MySQL testada e efetuada com sucesso!
# O número de registro é: 213418
#        id data_inversa dia_semana   horario  uf   br      km  \
# 0  496519   2023-01-01    domingo  02:00:00  ES  101   114.0
# 1  496543   2023-01-01    domingo  03:40:00  SP  116   113.1
# 2  496590   2023-01-01    domingo  01:40:00  MT  163  1112.0
# 3  496610   2023-01-01    domingo  10:40:00  PR  376   314.8
# 4  496659   2023-01-01    domingo  14:55:00  MG  116   569.4
#
#            municipio                            causa_acidente  \
# 0          SOORETAMA            Ausência de reação do condutor
# 1            TAUBATE             Entrada inopinada do pedestre
# 2  GUARANTA DO NORTE  Reação tardia ou ineficiente do condutor
# 3         ORTIGUEIRA                   Velocidade Incompatível
# 4           MANHUACU         Acumulo de água sobre o pavimento
#
#                tipo_acidente  ... ilesos ignorados feridos veiculos  \
# ...

# %%
from analises import AnaliseEstatistica

analise = AnaliseEstatistica(df)
media_normal = analise.calcular_media_diaria(eh_carnaval=0)
media_carnaval = analise.calcular_media_diaria(eh_carnaval=1)

taxa_crescimento = analise.calcular_variacao_percentual(media_carnaval, media_normal)

print(f'{taxa_crescimento:.2f}')
# Out:
# -4.09
